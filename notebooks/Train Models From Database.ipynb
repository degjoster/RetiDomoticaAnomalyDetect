# %%
pip install mlflow
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: mlflow in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (1.12.1)
# Requirement already satisfied: docker&gt;=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (4.4.0)
# Requirement already satisfied: protobuf&gt;=3.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (3.14.0)
# Requirement already satisfied: alembic&lt;=1.4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (1.4.1)
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.7/site-packages (from mlflow) (2.8.1)
# Requirement already satisfied: click&gt;=7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (7.1.2)
# Requirement already satisfied: querystring-parser in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: six&gt;=1.10.0 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (1.14.0)
# Requirement already satisfied: databricks-cli&gt;=0.8.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (0.14.1)
# Requirement already satisfied: requests&gt;=2.17.3 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: gunicorn in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (20.0.4)
# Requirement already satisfied: azure-storage-blob in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (12.6.0)
# Requirement already satisfied: sqlalchemy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (1.3.20)
# Requirement already satisfied: Flask in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (1.1.2)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.7/site-packages (from mlflow) (1.0.1)
# Requirement already satisfied: pyyaml in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (5.3.1)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.7/site-packages (from mlflow) (1.18.1)
# Requirement already satisfied: gitpython&gt;=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (3.1.11)
# Requirement already satisfied: prometheus-flask-exporter in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (0.18.1)
# Requirement already satisfied: entrypoints in /databricks/python3/lib/python3.7/site-packages (from mlflow) (0.3)
# Requirement already satisfied: sqlparse&gt;=0.3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (0.4.1)
# Requirement already satisfied: cloudpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (1.6.0)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from alembic&lt;=1.4.1-&gt;mlflow) (1.1.3)
# Requirement already satisfied: python-editor&gt;=0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from alembic&lt;=1.4.1-&gt;mlflow) (1.0.4)
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.7/site-packages (from mlflow) (2.8.1)
# Requirement already satisfied: sqlalchemy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (1.3.20)
# Requirement already satisfied: msrest&gt;=0.6.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from azure-storage-blob-&gt;mlflow) (0.6.19)
# Requirement already satisfied: azure-core&lt;2.0.0,&gt;=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from azure-storage-blob-&gt;mlflow) (1.9.0)
# Requirement already satisfied: cryptography&gt;=2.1.4 in /databricks/python3/lib/python3.7/site-packages (from azure-storage-blob-&gt;mlflow) (2.8)
# Requirement already satisfied: requests&gt;=2.17.3 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: six&gt;=1.10.0 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (1.14.0)
# Requirement already satisfied: cffi!=1.11.3,&gt;=1.8 in /databricks/python3/lib/python3.7/site-packages (from cryptography&gt;=2.1.4-&gt;azure-storage-blob-&gt;mlflow) (1.14.0)
# Requirement already satisfied: six&gt;=1.10.0 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (1.14.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.7/site-packages (from cffi!=1.11.3,&gt;=1.8-&gt;cryptography&gt;=2.1.4-&gt;azure-storage-blob-&gt;mlflow) (2.19)
# Requirement already satisfied: click&gt;=7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (7.1.2)
# Requirement already satisfied: tabulate&gt;=0.7.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from databricks-cli&gt;=0.8.7-&gt;mlflow) (0.8.7)
# Requirement already satisfied: six&gt;=1.10.0 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (1.14.0)
# Requirement already satisfied: requests&gt;=2.17.3 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: six&gt;=1.10.0 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (1.14.0)
# Requirement already satisfied: websocket-client&gt;=0.32.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from docker&gt;=4.0.0-&gt;mlflow) (0.57.0)
# Requirement already satisfied: requests&gt;=2.17.3 in /databricks/python3/lib/python3.7/site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: itsdangerous&gt;=0.24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from Flask-&gt;mlflow) (1.1.0)
# Requirement already satisfied: click&gt;=7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from mlflow) (7.1.2)
# Requirement already satisfied: Jinja2&gt;=2.10.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from Flask-&gt;mlflow) (2.11.2)
# Requirement already satisfied: Werkzeug&gt;=0.15 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from Flask-&gt;mlflow) (1.0.1)
# Requirement already satisfied: gitdb&lt;5,&gt;=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b3772c92-4d8e-4fc1-b48e-075a6b0c8e49/lib/python3.7/site-packages (from gitpython&gt;=2.1.0-&gt;mlflow) (4.0.5)
# Requir

# %%
# %run ./Common/DB_Utils
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import org.apache.spark.sql.{SparkSession, DataFrame}
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">jdbcHostname: String = aiengserver.database.windows.net
# jdbcPort: Int = 1433
# jdbcDatabase: String = CampusData
# jdbcUrl: String = jdbc:sqlserver://aiengserver.database.windows.net:1433;database=CampusData
# import java.util.Properties
# connectionProperties: java.util.Properties = {user=AzureUser, password=PasswordReti01}
# res15: Object = null
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">driverClass: String = com.microsoft.sqlserver.jdbc.SQLServerDriver
# res16: Object = null
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">CopyTableFromDB: (inputTableName: String, outputTableName: String)Int
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PushdownQueryToDB: (query: String)org.apache.spark.sql.DataFrame
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import mlflow
import mlflow.sklearn
import pandas as pd
import numpy as np

import os
import pickle

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import IsolationForest
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Caricamento dei dati in PySpark e conversione in dataframe Pandas

# %%
# %scala
CopyTableFromDB("dbo.Log", "log")
CopyTableFromDB("[dbo].[Group]", "group")
CopyTableFromDB("dbo.Building", "building")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res23: Int = 0
# </div>

# %%
df_log = spark.sql('select * from log').toPandas()
df_group = spark.sql('select * from group').toPandas()
df_building = spark.sql('select * from building').toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_log.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data</th>
#       <th>IdBuilding</th>
#       <th>IndividualAddress</th>
#       <th>GroupAddress</th>
#       <th>TelegramType</th>
#       <th>Value</th>
#       <th>ValueType</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2019-02-22 12:27:53.323333</td>
#       <td>1</td>
#       <td>3.1.6</td>
#       <td>2/2/0</td>
#       <td>write</td>
#       <td>-33429.7</td>
#       <td>W</td>
#       <td>Produzione totale fotovoltaico</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2019-02-22 12:28:56.400000</td>
#       <td>1</td>
#       <td>3.1.201</td>
#       <td>2/0/3</td>
#       <td>write</td>
#       <td>35.68625</td>
#       <td>%</td>
#       <td>C1/0/M102 Umidità</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2019-02-22 12:29:37.176666</td>
#       <td>1</td>
#       <td>3.2.202</td>
#       <td>2/0/0</td>
#       <td>write</td>
#       <td>400.96</td>
#       <td>ppm</td>
#       <td>C1/0/M101 CO2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2019-02-22 12:30:21.933333</td>
#       <td>1</td>
#       <td>3.3.201</td>
#       <td>2/1/8</td>
#       <td>write</td>
#       <td>36.86272</td>
#       <td>%</td>
#       <td>C1/0/U105 Umidità</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2019-02-22 12:31:23.480000</td>
#       <td>1</td>
#       <td>3.3.202</td>
#       <td>2/1/0</td>
#       <td>write</td>
#       <td>536.96</td>
#       <td>ppm</td>
#       <td>C1/0/U101 C02</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_group.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>IdBuilding</th>
#       <th>GroupAddress</th>
#       <th>DataPoint</th>
#       <th>ValueType</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>2/0/0</td>
#       <td>9</td>
#       <td>ppm</td>
#       <td>C1/0/M101 CO2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>2/0/1</td>
#       <td>9</td>
#       <td>ppm</td>
#       <td>C1/0/M102 CO2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1</td>
#       <td>2/1/0</td>
#       <td>9</td>
#       <td>ppm</td>
#       <td>C1/0/U101 C02</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>1</td>
#       <td>2/1/1</td>
#       <td>9</td>
#       <td>ppm</td>
#       <td>C1/0/U105 C02</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2/0/4</td>
#       <td>9</td>
#       <td>C°</td>
#       <td>C1/0/M101 TEMP</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_building.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>Nome</th>
#       <th>Ip</th>
#       <th>TabStorico</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Edificio1</td>
#       <td>10.2.1.142</td>
#       <td>LogEdificioUno</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Edificio2</td>
#       <td>10.2.3.254</td>
#       <td>LogEdificioDue</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>Edificio3</td>
#       <td>10.2.3.22</td>
#       <td>LogEdificioTre</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>Villa</td>
#       <td>10.2.3.14</td>
#       <td>LogVilla</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Definizione delle funzioni principali per il preprocessing e il training del modello

# %%
def signals_selection(logs, groups):
    
    # Rimuove le rilevazioni di tipo boolean, quelle non mappate nel dataset "group" e quelle che non presentano un valore nei
    # campi "Data", "Value" e "Id". Restituisce un dataframe di segnali che saranno effettivamente preprocessati e passati
    # come input al modello per l'addestramento
    
    # Unità di misura da tenere e tipologie di rilevazioni da rimuovere
    measures_to_keep = ['ppm', 'C°', '%', 'W', 'Wh']
    # description_to_remove = ['Daikin Active Power Total','Consumo enel di E1 + Villa']
    
     # Rimuovo i record associati a rilevazioni di tipo booleano
    logs = logs[logs['ValueType'].isin(measures_to_keep) == True]
    
    # Rimuovo i record associati a rilevazioni di tipo "Daikin Active Power Total" e "Consumo Enel di E1 + Villa"
    #logs = logs[logs['Description'].isin(description_to_remove) == False]
    
    # Effettuo il left join con la tabella group per ricavare l'ID della rilevazione
    logs = logs.merge(groups[['Description', 'Id']], how='left', on='Description')
    logs = logs.dropna(subset=['Data', 'Id', 'Value']).reset_index(drop=True)
    
    # Converto la colonna 'Data' in formato datetime
    logs['Data'] = pd.to_datetime(logs['Data'])
    
    # Converto la colonna 'Value' in formato numerico
    logs["Value"] = pd.to_numeric(np.char.replace(logs['Value'].to_numpy().astype(str),',','.'))
    
    return logs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def preprocessing(sel_logs):
    
    # Ricavo il mese e il giorno della settimana della rilevazione
    sel_logs['Month'] = pd.DatetimeIndex(sel_logs['Data']).month
    sel_logs['Weekday'] = pd.DatetimeIndex(sel_logs['Data']).weekday
    
    # 3) Rimuovo le features che non servono ad addestrare il modello
    features_to_drop = ['Data', 'IdBuilding', 'IndividualAddress', 'GroupAddress', 'TelegramType', 'ValueType', 'Description']
    sel_logs = sel_logs.drop(columns=features_to_drop)   
    
    return sel_logs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def forest_train_save(train_logs, model_name, num_est=100, cnt_rate=0.01):
  
  with mlflow.start_run(run_name=model_name) as run:
    iso_forest = IsolationForest(n_estimators=num_est, random_state=19, contamination=cnt_rate, behaviour='deprecated').fit(train_logs)

    # Log parameters and metrics using the MLflow APIs
    mlflow.log_params({"n_estimators": num_est, "contamination_rate": cnt_rate})

    # Log the sklearn model and register as version 1
    mlflow.sklearn.log_model(
        sk_model=iso_forest,
        artifact_path="sklearn-model",
        registered_model_name=model_name
    )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Run del training dei modelli

# %%
sel_logs = signals_selection(df_log, df_group)
sel_logs.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data</th>
#       <th>IdBuilding</th>
#       <th>IndividualAddress</th>
#       <th>GroupAddress</th>
#       <th>TelegramType</th>
#       <th>Value</th>
#       <th>ValueType</th>
#       <th>Description</th>
#       <th>Id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2019-02-22 12:27:53.323333</td>
#       <td>1</td>
#       <td>3.1.6</td>
#       <td>2/2/0</td>
#       <td>write</td>
#       <td>-33429.70000</td>
#       <td>W</td>
#       <td>Produzione totale fotovoltaico</td>
#       <td>13.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2019-02-22 12:28:56.400000</td>
#       <td>1</td>
#       <td>3.1.201</td>
#       <td>2/0/3</td>
#       <td>write</td>
#       <td>35.68625</td>
#       <td>%</td>
#       <td>C1/0/M102 Umidità</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2019-02-22 12:29:37.176666</td>
#       <td>1</td>
#       <td>3.2.202</td>
#       <td>2/0/0</td>
#       <td>write</td>
#       <td>400.96000</td>
#       <td>ppm</td>
#       <td>C1/0/M101 CO2</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2019-02-22 12:30:21.933333</td>
#       <td>1</td>
#       <td>3.3.201</td>
#       <td>2/1/8</td>
#       <td>write</td>
#       <td>36.86272</td>
#       <td>%</td>
#       <td>C1/0/U105 Umidità</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2019-02-22 12:31:23.480000</td>
#       <td>1</td>
#       <td>3.3.202</td>
#       <td>2/1/0</td>
#       <td>write</td>
#       <td>536.96000</td>
#       <td>ppm</td>
#       <td>C1/0/U101 C02</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Train del modello per CO2
train_logs = preprocessing(sel_logs[sel_logs['ValueType'] == 'ppm'])
forest_model = forest_train_save(train_logs, model_name="team1_CO2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1607288739344-0/PythonShell.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Databricks Python Shell
# /local_disk0/tmp/1607288739344-0/PythonShell.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #
# Successfully registered model &#39;team1_CO2&#39;.
# 2020/12/06 22:07:35 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: team1_CO2, version 1
# Created version &#39;1&#39; of model &#39;team1_CO2&#39;.
# </div>

# %%
# Train del modello per umidità
train_logs = preprocessing(sel_logs[sel_logs['ValueType'] == '%'])
forest_model = forest_train_save(train_logs, model_name="team1_umidita")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1607288739344-0/PythonShell.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Databricks Python Shell
# /local_disk0/tmp/1607288739344-0/PythonShell.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #
# Successfully registered model &#39;team1_umidita&#39;.
# 2020/12/06 22:08:27 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: team1_umidita, version 1
# Created version &#39;1&#39; of model &#39;team1_umidita&#39;.
# </div>

# %%
# Train del modello per temperatura
train_logs = preprocessing(sel_logs[sel_logs['ValueType'] == 'C°'])
forest_model = forest_train_save(train_logs, model_name="team1_temperatura")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1607288739344-0/PythonShell.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Databricks Python Shell
# /local_disk0/tmp/1607288739344-0/PythonShell.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #
# Successfully registered model &#39;team1_temperatura&#39;.
# 2020/12/06 22:08:56 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: team1_temperatura, version 1
# Created version &#39;1&#39; of model &#39;team1_temperatura&#39;.
# </div>

# %%
# Train del modello per Watt
train_logs = preprocessing(sel_logs[sel_logs['ValueType'] == 'W'])
forest_model = forest_train_save(train_logs, model_name="team1_W")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1607288739344-0/PythonShell.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Databricks Python Shell
# /local_disk0/tmp/1607288739344-0/PythonShell.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #
# Successfully registered model &#39;team1_W&#39;.
# 2020/12/06 22:09:37 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: team1_W, version 1
# Created version &#39;1&#39; of model &#39;team1_W&#39;.
# </div>

# %%
# Train del modello per Wh
train_logs = preprocessing(sel_logs[sel_logs['ValueType'] == 'Wh'])
forest_model = forest_train_save(train_logs, model_name="team1_Wh")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1607288739344-0/PythonShell.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Databricks Python Shell
# /local_disk0/tmp/1607288739344-0/PythonShell.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #
# Successfully registered model &#39;team1_Wh&#39;.
# 2020/12/06 22:09:55 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: team1_Wh, version 1
# Created version &#39;1&#39; of model &#39;team1_Wh&#39;.
# </div>
